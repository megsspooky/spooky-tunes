# %% [markdown]
# <a href="https://colab.research.google.com/github/megsspooky/spooky-tunes/blob/main/AI_noise_art.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

cmaps = ['plasma', 'inferno', 'magma', 'twilight', 'cubehelix', 'nipy_spectral']
chosen = random.choice(cmaps)

plt.imshow(image, cmap=chosen)
plt.title(f"Spooky Noise Art with '{chosen}' colormap")
# Out:
# Text(0.5, 1.0, "Spooky Noise Art with 'magma' colormap")
